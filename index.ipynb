# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a dataset which contains information on World Cup matches. Let's use the Pandas commands learned in the previous lesson to learn more about our data!

# %% [markdown]
# ## Objectives
# You will be able to:
# - Use pandas methods and attributes to access information about a dataset
# - Index pandas dataframes with .loc, .iloc, and column names
# - Use a boolean mask to index pandas series and dataframes

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load the file `'WorldCupMatches.csv'` as a DataFrame in Pandas.

# %%
# Import pandas using the standard alias
import pandas as pd

# Import 'WorldCupMatches.csv' as a DataFrame
df = pd.read_csv('WorldCupMatches.csv',index_col=None)

# %% [markdown]
# ## Common methods and attributes

# %% [markdown]
# Use the correct method to look at the first 7 rows of the dataset.

# %%
# Print the first 7 rows of df
df.head(7)
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
# 6     Yugoslavia                4                0        Bolivia
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
# 6                    18306.0                     0                     0
#
#                     Referee               Assistant 1  \
# 0    LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)    LOMBARDI Domingo (URU)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
# 5         LANGENUS Jean (BEL)      201     1095                CHI
# 6       WARNKEN Alberto (CHI)      201     1092                YUG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA
# 5                MEX
# 6                BOL

# %% [markdown]
# Look at the last 3 rows of the data set.

# %%
# Print the last 3 rows of df
df.tail(3)
# Out:
#      Year              Datetime                     Stage  \
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                       Win conditions  \
# 849                0      Argentina  Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina        Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                    Referee            Assistant 1              Assistant 2  \
# 849     C�neyt �AKIR (TUR)   DURAN Bahattin (TUR)        ONGUN Tarik (TUR)
# 850  HAIMOUDI Djamel (ALG)   ACHIK Redouane (MAR)  ETCHIALI Abdelhak (ALG)
# 851   Nicola RIZZOLI (ITA)  Renato FAVERANI (ITA)     Andrea STEFANI (ITA)
#
#      RoundID    MatchID Home Team Initials Away Team Initials
# 849   255955  300186490                NED                ARG
# 850   255957  300186502                BRA                NED
# 851   255959  300186501                GER                ARG

# %% [markdown]
# Get a concise summary of the data using `.info()`.

# %%
# Print a concise summary of df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
# Year                    852 non-null int64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null int64
# Away Team Goals         852 non-null int64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null int64
# Half-time Away Goals    852 non-null int64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null int64
# MatchID                 852 non-null int64
# Home Team Initials      852 non-null object
# Away Team Initials      852 non-null object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 133.2+ KB

# %% [markdown]
# Obtain a tuple representing the number of rows and number of columns

# %%
# Print the number of rows and columns in df
df.shape
# Out:
# (852, 20)

# %% [markdown]
# Use the appropriate attribute to get the column names

# %%
# Print the column names of df
print(df.columns)
print(df.columns.get_loc('MatchID'))
print(df.columns.get_loc('City'))
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')
# 17
# 4

# %% [markdown]
# ## Selecting DataFrame information

# %% [markdown]
# When looking at the DataFrame's `.head()`, you might have noticed that the games are structured chronologically in the DataFrame.
#
# Use the right selection method to print all the information from the 3rd to the 5th game.

# %%
# Print rows 3 through 5
df.iloc[3:6]
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
#
#                  Referee              Assistant 1                 Assistant 2  \
# 3  WARNKEN Alberto (CHI)      LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)
# 4    REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)
# 5  CRISTOPHE Henry (BEL)  APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 3      201     1098                ROU                PER
# 4      201     1085                ARG                FRA
# 5      201     1095                CHI                MEX

# %% [markdown]
# Now, print all the info from game 5-9, but we're only interested in printing out the, "Home Team Name" and the, "Away Team Name."

# %%
# Print rows 5 through 9 and columns 'Home Team Name' and 'Away Team Name'
print(df.loc[5:9,['Home Team Name','Away Team Name']])
df.loc[5:9, (df.columns == 'Home Team Name') | (df.columns == 'Away Team Name')]
# Out:
#   Home Team Name Away Team Name
# 5          Chile         Mexico
# 6     Yugoslavia        Bolivia
# 7            USA       Paraguay
# 8        Uruguay           Peru
# 9          Chile         France
#   Home Team Name Away Team Name
# 5          Chile         Mexico
# 6     Yugoslavia        Bolivia
# 7            USA       Paraguay
# 8        Uruguay           Peru
# 9          Chile         France

# %% [markdown]
# Next, we'd like the information on all the games played in Group 3 for the 1950 World Cup.

# %%
# Print all info for games played in 1950 for Group 3
print(type(df.Stage))
print(df.Stage.dtypes,'\n\n')
print(df.loc[(df.Stage == 'Group 3') & (df.Year == 1950)],'\n\n')
df[(df.Stage == 'Group 3') & (df.Year == 1950)]
# Out:
# <class 'pandas.core.series.Series'>
# object
#
#
#     Year              Datetime    Stage           Stadium        City  \
# 56  1950  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden                3                2          Italy
# 61         Sweden                2                2       Paraguay
# 65          Italy                2                0       Paraguay
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 56                    36502.0                     2                     1
# 61                     7903.0                     2                     1
# 65                    25811.0                     1                     0
#
#                   Referee             Assistant 1                Assistant 2  \
# 56        LUTZ Jean (SUI)     BERANEK Alois (AUT)        TEJADA Carlos (MEX)
# 61  MITCHELL Robert (SCO)       LEMESIC Leo (YUG)     GARCIA Prudencio (USA)
# 65     ELLIS Arthur (ENG)  GARCIA Prudencio (USA)  DE LA SALLE Charles (FRA)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 56      208     1219                SWE                ITA
# 61      208     1228                SWE                PAR
# 65      208     1218                ITA                PAR
#     Year              Datetime    Stage           Stadium        City  \
# 56  1950  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden                3                2          Italy
# 61         Sweden                2                2       Paraguay
# 65          Italy                2                0       Paraguay
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 56                    36502.0                     2                     1
# 61                     7903.0                     2                     1
# 65                    25811.0                     1                     0
#
#                   Referee             Assistant 1                Assistant 2  \
# 56        LUTZ Jean (SUI)     BERANEK Alois (AUT)        TEJADA Carlos (MEX)
# 61  MITCHELL Robert (SCO)       LEMESIC Leo (YUG)     GARCIA Prudencio (USA)
# 65     ELLIS Arthur (ENG)  GARCIA Prudencio (USA)  DE LA SALLE Charles (FRA)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 56      208     1219                SWE                ITA
# 61      208     1228                SWE                PAR
# 65      208     1218                ITA                PAR

# %% [markdown]
# Let's repeat the command above, but now we only want to print out the attendance column for the Group 3 games.

# %% [markdown]
# You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %%
# Print the 'Attendance' column for games played in 1950 for Group 3
df.loc[(df.Stage == 'Group 3') & (df.Year == 1950),['Attendance']]
# Out:
#     Attendance
# 56     36502.0
# 61      7903.0
# 65     25811.0

# %% [markdown]
# Throughout the entire history of the World Cup, how many home games were played by the Netherlands?

# %%
# Number of home games played by the Netherlands
print(len(df[df['Home Team Name'] == 'Netherlands']))
df[df['Home Team Name'] == 'Netherlands']
# Out:
# 32
#      Year               Datetime                  Stage  \
# 244  1974   19 Jun 1974 - 19:30                 Group 3
# 258  1974   26 Jun 1974 - 19:30                 Group A
# 265  1974   03 Jul 1974 - 19:30                 Group A
# 269  1974  07 July 1974 - 16:00                   Final
# 277  1978   03 Jun 1978 - 16:45                 Group 4
# 285  1978   07 Jun 1978 - 16:45                 Group 4
# 295  1978   14 Jun 1978 - 13:45                 Group A
# 302  1978   21 Jun 1978 - 13:45                 Group A
# 422  1990   12 Jun 1990 - 21:00                 Group F
# 472  1994   20 Jun 1994 - 19:30                 Group F
# 504  1994   04 Jul 1994 - 12:00             Round of 16
# 509  1994   09 Jul 1994 - 14:30          Quarter-finals
# 525  1998   13 Jun 1998 - 21:00                 Group E
# 542  1998   20 Jun 1998 - 21:00                 Group E
# 557  1998   25 Jun 1998 - 16:00                 Group E
# 569  1998   29 Jun 1998 - 21:00             Round of 16
# 574  1998   04 Jul 1998 - 16:30          Quarter-finals
# 578  1998   11 Jul 1998 - 21:00   Match for third place
# 665  2006   16 Jun 2006 - 18:00                 Group C
# 682  2006   21 Jun 2006 - 21:00                 Group C
# 716  2010   14 Jun 2010 - 13:30                 Group E
# 731  2010   19 Jun 2010 - 13:30                 Group E
# 760  2010   28 Jun 2010 - 16:00             Round of 16
# 764  2010   02 Jul 2010 - 16:00          Quarter-finals
# 771  2010   11 Jul 2010 - 20:30                   Final
# 805  2014   23 Jun 2014 - 13:00                 Group B
# 829  2014   09 Jul 2014 - 17:00             Semi-finals
# 830  2014   05 Jul 2014 - 17:00          Quarter-finals
# 832  2014   29 Jun 2014 - 13:00             Round of 16
# 838  2014   29 Jun 2014 - 13:00             Round of 16
# 847  2014   05 Jul 2014 - 17:00          Quarter-finals
# 849  2014   09 Jul 2014 - 17:00             Semi-finals
#
#                                                Stadium  \
# 244                                   Westfalenstadion
# 258                                        Parkstadion
# 265                                   Westfalenstadion
# 269                                     Olympiastadion
# 277                                         San Martin
# 285                                         San Martin
# 295                  Estadio Ol�mpico Chateau Carreras
# 302  El Monumental - Estadio Monumental Antonio Ves...
# 422                                     Della Favorita
# 472                                        RFK Stadium
# 504                                        Citrus Bowl
# 509                                        Cotton Bowl
# 525                                    Stade de France
# 542                                    Stade V�lodrome
# 557                            Stade Geoffroy Guichard
# 569                                    Stade Municipal
# 574                                    Stade V�lodrome
# 578                                   Parc des Princes
# 665                           Gottlieb-Daimler-Stadion
# 682                  FIFA World Cup Stadium, Frankfurt
# 716                                Soccer City Stadium
# 731                                     Durban Stadium
# 760                                     Durban Stadium
# 764                             Port Elizabeth Stadium
# 771                                Soccer City Stadium
# 805                                 Arena de Sao Paulo
# 829                                 Arena de Sao Paulo
# 830                                   Arena Fonte Nova
# 832                                   Estadio Castelao
# 838                                   Estadio Castelao
# 847                                   Arena Fonte Nova
# 849                                 Arena de Sao Paulo
#
#                                    City Home Team Name  Home Team Goals  \
# 244                           Dortmund     Netherlands                0
# 258                      Gelsenkirchen     Netherlands                4
# 265                           Dortmund     Netherlands                2
# 269                             Munich     Netherlands                1
# 277                            Mendoza     Netherlands                3
# 285                            Mendoza     Netherlands                0
# 295                            Cordoba     Netherlands                5
# 302                       Buenos Aires     Netherlands                2
# 422                            Palermo     Netherlands                1
# 472                      Washington Dc     Netherlands                2
# 504                            Orlando     Netherlands                2
# 509                             Dallas     Netherlands                2
# 525                        Saint-Denis     Netherlands                0
# 542                         Marseilles     Netherlands                5
# 557                      Saint-Etienne     Netherlands                2
# 569                           Toulouse     Netherlands                2
# 574                         Marseilles     Netherlands                2
# 578                              Paris     Netherlands                1
# 665                          Stuttgart     Netherlands                2
# 682                     Frankfurt/Main     Netherlands                0
# 716                       Johannesburg     Netherlands                2
# 731                             Durban     Netherlands                1
# 760                             Durban     Netherlands                2
# 764  Nelson Mandela Bay/Port Elizabeth     Netherlands                2
# 771                       Johannesburg     Netherlands                0
# 805                          Sao Paulo     Netherlands                2
# 829                          Sao Paulo     Netherlands                0
# 830                           Salvador     Netherlands                0
# 832                          Fortaleza     Netherlands                2
# 838                          Fortaleza     Netherlands                2
# 847                           Salvador     Netherlands                0
# 849                          Sao Paulo     Netherlands                0
#
#      Away Team Goals           Away Team Name  \
# 244                0                   Sweden
# 258                0                Argentina
# 265                0                   Brazil
# 269                2               Germany FR
# 277                0                  IR Iran
# 285                0                     Peru
# 295                1                  Austria
# 302                1                    Italy
# 422                1                    Egypt
# 472                1             Saudi Arabia
# 504                0  rn">Republic of Ireland
# 509                3                   Brazil
# 525                0                  Belgium
# 542                0           Korea Republic
# 557                2                   Mexico
# 569                1               Yugoslavia
# 574                1                Argentina
# 578                2                  Croatia
# 665                1            C�te d'Ivoire
# 682                0                Argentina
# 716                0                  Denmark
# 731                0                    Japan
# 760                1                 Slovakia
# 764                1                   Brazil
# 771                1                    Spain
# 805                0                    Chile
# 829                0                Argentina
# 830                0               Costa Rica
# 832                1                   Mexico
# 838                1                   Mexico
# 847                0               Costa Rica
# 849                0                Argentina
#
#                             Win conditions  Attendance  Half-time Home Goals  \
# 244                                            53700.0                     0
# 258                                            56548.0                     2
# 265                                            53700.0                     0
# 269                                            78200.0                     1
# 277                                            33431.0                     1
# 285                                            28125.0                     0
# 295                                            25050.0                     3
# 302                                            67433.0                     0
# 422                                            33288.0                     0
# 472                                            50535.0                     0
# 504                                            61355.0                     2
# 509                                            63500.0                     0
# 525                                            77000.0                     0
# 542                                            55000.0                     2
# 557                                            30600.0                     2
# 569                                            33500.0                     1
# 574                                            55000.0                     1
# 578                                            45500.0                     1
# 665                                            52000.0                     2
# 682                                            48000.0                     0
# 716                                            83465.0                     0
# 731                                            62010.0                     0
# 760                                            61962.0                     1
# 764                                            40186.0                     0
# 771            Spain win after extra time      84490.0                     0
# 805                                            62996.0                     0
# 829    Argentina win on penalties (2 - 4)      63267.0                     0
# 830  Netherlands win on penalties (4 - 3)      51179.0                     0
# 832                                            58817.0                     0
# 838                                            58817.0                     0
# 847  Netherlands win on penalties (4 - 3)      51179.0                     0
# 849    Argentina win on penalties (2 - 4)      63267.0                     0
#
#      Half-time Away Goals                           Referee  \
# 244                     0            WINSEMANN Werner (CAN)
# 258                     0                DAVIDSON Bob (SCO)
# 265                     0            TSCHENSCHER Kurt (GER)
# 269                     2                 TAYLOR John (ENG)
# 277                     0  GONZALEZ ARCHUNDIA Alfonso (MEX)
# 285                     0                PROKOP Adolf (GDR)
# 295                     0                 GORDON John (SCO)
# 302                     1              MARTINEZ Angel (ESP)
# 422                     0      SORIANO ALADREN Emilio (ESP)
# 472                     1            DIAZ VEGA Manuel (ESP)
# 504                     0             MIKKELSEN Peter (DEN)
# 509                     0             BADILLA Rodrigo (CRC)
# 525                     0           COLLINA Pierluigi (ITA)
# 542                     0              WOJCIK Ryszard (POL)
# 557                     0          ALZEID Abdulrahman (KSA)
# 569                     0    GARCIA ARANDA Jose Maria (ESP)
# 574                     1        BRIZIO CARTER Arturo (MEX)
# 578                     2    GONZALEZ CHAVEZ Epifanio (PAR)
# 665                     1                  RUIZ Oscar (COL)
# 682                     0       MEDINA CANTALEJO Luis (ESP)
# 716                     0             St�phane LANNOY (FRA)
# 731                     0             BALDASSI Hector (ARG)
# 760                     0    Alberto UNDIANO MALLENCO (ESP)
# 764                     1            NISHIMURA Yuichi (JPN)
# 771                     0                 WEBB Howard (ENG)
# 805                     0              Bakary GASSAMA (GAM)
# 829                     0                C�neyt �AKIR (TUR)
# 830                     0             Ravshan IRMATOV (UZB)
# 832                     0               PROENCA Pedro (POR)
# 838                     0               PROENCA Pedro (POR)
# 847                     0             Ravshan IRMATOV (UZB)
# 849                     0                C�neyt �AKIR (TUR)
#
#                             Assistant 1                           Assistant 2  \
# 244              TSCHENSCHER Kurt (GER)                    THOMAS Clive (WAL)
# 258              TSCHENSCHER Kurt (GER)                   KAZAKOV Pavel (URS)
# 265                  DAVIDSON Bob (SCO)                  SUPPIAH George (SIN)
# 269    GONZALEZ ARCHUNDIA Alfonso (MEX)              BARRETO RUIZ Ramon (URU)
# 277                  WURTZ Robert (FRA)                 COMESANA Miguel (ARG)
# 285       COEREZZA Norberto Angel (ARG)                  IVANOV Anatoly (URS)
# 295      ITHURRALDE Arturo Andres (ARG)                    BOUZO Farouk (SYR)
# 302                PESTARINO Luis (ARG)           OROZCO GUERRERO Cesar (PER)
# 422        CODESAL MENDEZ Edgardo (MEX)  CARDELLINO DE SAN VICENTE Juan (URU)
# 472               IVANOV Valentin (RUS)                   MARTON Sandor (HUN)
# 504                DUNSTER Gordon (AUS)                 BRAZZALE Eugene (AUS)
# 509     AL GHATTAN Yousif Abdulla (BAH)                 FANAEI Mohammad (IRN)
# 525                MAZZEI Gennaro (ITA)                  ZAMMIT Emanuel (MLT)
# 542               POCIEGIEL Jacek (POL)                    DUPANOV Yuri (BLR)
# 557       TRESACO GRACIA Fernando (ESP)              GHADANFARI Hussain (KUW)
# 569                RAUSIS Laurent (SUI)              GRIGORESCU Nicolae (ROU)
# 574                   POWELL Owen (JAM)                SALINAS Reynaldo (HON)
# 578                ZAMMIT Emanuel (MLT)                     FRED Lencie (VAN)
# 665               TAMAYO Fernando (ECU)                      NAVIA Jose (COL)
# 682  GIRALDEZ CARRASCO Victoriano (ESP)          MEDINA HERNANDEZ Pedro (ESP)
# 716                 DANSAULT Eric (FRA)                     UGO Laurent (FRA)
# 731                 CASAS Ricardo (ARG)                  MAIDANA Hernan (ARG)
# 760               MARTINEZ Fermin (ESP)                      YUSTE Juan (ESP)
# 764                   SAGARA Toru (JPN)                  JEONG Hae Sang (KOR)
# 771                   Darren CANN (ENG)               MULLARKEY Michael (ENG)
# 805            MENKOUANDE Evarist (CMR)                KABANDA Felicien (RWA)
# 829                DURAN Bahattin (TUR)                     ONGUN Tarik (TUR)
# 830         RASULOV Abduxamidullo (UZB)              KOCHKAROV Bakhadyr (KGZ)
# 832               MIRANDA Bertino (POR)                      TRIGO Jose (POR)
# 838               MIRANDA Bertino (POR)                      TRIGO Jose (POR)
# 847         RASULOV Abduxamidullo (UZB)              KOCHKAROV Bakhadyr (KGZ)
# 849                DURAN Bahattin (TUR)                     ONGUN Tarik (TUR)
#
#       RoundID    MatchID Home Team Initials Away Team Initials
# 244       262       2097                NED                SWE
# 258       263       1948                NED                ARG
# 265       263       1983                NED                BRA
# 269       605       2063                NED                FRG
# 277       278       2388                NED                IRN
# 285       278       2394                NED                PER
# 295       279       2220                NED                AUT
# 302       279       2391                NED                ITA
# 422       322        151                NED                EGY
# 472       337       3058                NED                KSA
# 504       338       3089                NED                IRL
# 509       796       3098                NED                BRA
# 525      1014       8733                NED                BEL
# 542      1014       8749                NED                KOR
# 557      1014       8766                NED                MEX
# 569      1024       8778                NED                YUG
# 574      1025       8784                NED                ARG
# 578      1028       8787                NED                CRO
# 665  97410100   97410022                NED                CIV
# 682  97410100   97410037                NED                ARG
# 716    249722  300061478                NED                DEN
# 731    249722  300111117                NED                JPN
# 760    249717  300111113                NED                SVK
# 764    249718  300061507                NED                BRA
# 771    249721  300061509                NED                ESP
# 805    255931  300186470                NED                CHI
# 829    255955  300186490                NED                ARG
# 830    255953  300186488                NED                CRC
# 832    255951  300186508                NED                MEX
# 838    255951  300186508                NED                MEX
# 847    255953  300186488                NED                CRC
# 849    255955  300186490                NED                ARG

# %% [markdown]
# How many games were played by the Netherlands in total?

# %%
# Number of games played by the Netherlands in total
print(len(df[(df['Home Team Name'] == 'Netherlands') | (df['Away Team Name'] == 'Netherlands')]))
df[(df['Home Team Name'] == 'Netherlands') | (df['Away Team Name'] == 'Netherlands')]
# Out:
# 54
#      Year               Datetime                     Stage  \
# 20   1934   27 May 1934 - 16:30          Preliminary round
# 41   1938   05 Jun 1938 - 18:30                First round
# 236  1974   15 Jun 1974 - 16:00                    Group 3
# 244  1974   19 Jun 1974 - 19:30                    Group 3
# 252  1974   23 Jun 1974 - 16:00                    Group 3
# 258  1974   26 Jun 1974 - 19:30                    Group A
# 262  1974   30 Jun 1974 - 16:00                    Group A
# 265  1974   03 Jul 1974 - 19:30                    Group A
# 269  1974  07 July 1974 - 16:00                      Final
# 277  1978   03 Jun 1978 - 16:45                    Group 4
# 285  1978   07 Jun 1978 - 16:45                    Group 4
# 293  1978   11 Jun 1978 - 16:45                    Group 4
# 295  1978   14 Jun 1978 - 13:45                    Group A
# 300  1978   18 Jun 1978 - 16:45                    Group A
# 302  1978   21 Jun 1978 - 13:45                    Group A
# 307  1978   25 Jun 1978 - 15:00                      Final
# 422  1990   12 Jun 1990 - 21:00                    Group F
# 432  1990   16 Jun 1990 - 21:00                    Group F
# 446  1990   21 Jun 1990 - 21:00                    Group F
# 451  1990   24 Jun 1990 - 21:00                Round of 16
# 472  1994   20 Jun 1994 - 19:30                    Group F
# 484  1994   25 Jun 1994 - 12:30                    Group F
# 496  1994   29 Jun 1994 - 12:30                    Group F
# 504  1994   04 Jul 1994 - 12:00                Round of 16
# 509  1994   09 Jul 1994 - 14:30             Quarter-finals
# 525  1998   13 Jun 1998 - 21:00                    Group E
# 542  1998   20 Jun 1998 - 21:00                    Group E
# 557  1998   25 Jun 1998 - 16:00                    Group E
# 569  1998   29 Jun 1998 - 21:00                Round of 16
# 574  1998   04 Jul 1998 - 16:30             Quarter-finals
# 576  1998   07 Jul 1998 - 21:00                Semi-finals
# 578  1998   11 Jul 1998 - 21:00      Match for third place
# 649  2006   11 Jun 2006 - 15:00                    Group C
# 665  2006   16 Jun 2006 - 18:00                    Group C
# 682  2006   21 Jun 2006 - 21:00                    Group C
# 695  2006   25 Jun 2006 - 21:00                Round of 16
# 716  2010   14 Jun 2010 - 13:30                    Group E
# 731  2010   19 Jun 2010 - 13:30                    Group E
# 751  2010   24 Jun 2010 - 20:30                    Group E
# 760  2010   28 Jun 2010 - 16:00                Round of 16
# 764  2010   02 Jul 2010 - 16:00             Quarter-finals
# 768  2010   06 Jul 2010 - 20:30                Semi-finals
# 771  2010   11 Jul 2010 - 20:30                      Final
# 774  2014   13 Jun 2014 - 16:00                    Group B
# 789  2014   18 Jun 2014 - 13:00                    Group B
# 805  2014   23 Jun 2014 - 13:00                    Group B
# 827  2014   12 Jul 2014 - 17:00   Play-off for third place
# 829  2014   09 Jul 2014 - 17:00                Semi-finals
# 830  2014   05 Jul 2014 - 17:00             Quarter-finals
# 832  2014   29 Jun 2014 - 13:00                Round of 16
# 838  2014   29 Jun 2014 - 13:00                Round of 16
# 847  2014   05 Jul 2014 - 17:00             Quarter-finals
# 849  2014   09 Jul 2014 - 17:00                Semi-finals
# 850  2014   12 Jul 2014 - 17:00   Play-off for third place
#
#                                                Stadium  \
# 20                                            San Siro
# 41                                         Cavee Verte
# 236                               Niedersachsenstadion
# 244                                   Westfalenstadion
# 252                                   Westfalenstadion
# 258                                        Parkstadion
# 262                                        Parkstadion
# 265                                   Westfalenstadion
# 269                                     Olympiastadion
# 277                                         San Martin
# 285                                         San Martin
# 293                                         San Martin
# 295                  Estadio Ol�mpico Chateau Carreras
# 300                  Estadio Ol�mpico Chateau Carreras
# 302  El Monumental - Estadio Monumental Antonio Ves...
# 307  El Monumental - Estadio Monumental Antonio Ves...
# 422                                     Della Favorita
# 432                                          Sant Elia
# 446                                     Della Favorita
# 451                                    Giuseppe Meazza
# 472                                        RFK Stadium
# 484                                        Citrus Bowl
# 496                                        Citrus Bowl
# 504                                        Citrus Bowl
# 509                                        Cotton Bowl
# 525                                    Stade de France
# 542                                    Stade V�lodrome
# 557                            Stade Geoffroy Guichard
# 569                                    Stade Municipal
# 574                                    Stade V�lodrome
# 576                                    Stade V�lodrome
# 578                                   Parc des Princes
# 649                                     Zentralstadion
# 665                           Gottlieb-Daimler-Stadion
# 682                  FIFA World Cup Stadium, Frankfurt
# 695                                    Franken-Stadion
# 716                                Soccer City Stadium
# 731                                     Durban Stadium
# 751                                  Cape Town Stadium
# 760                                     Durban Stadium
# 764                             Port Elizabeth Stadium
# 768                                  Cape Town Stadium
# 771                                Soccer City Stadium
# 774                                   Arena Fonte Nova
# 789                                  Estadio Beira-Rio
# 805                                 Arena de Sao Paulo
# 827                                   Estadio Nacional
# 829                                 Arena de Sao Paulo
# 830                                   Arena Fonte Nova
# 832                                   Estadio Castelao
# 838                                   Estadio Castelao
# 847                                   Arena Fonte Nova
# 849                                 Arena de Sao Paulo
# 850                                   Estadio Nacional
#
#                                    City             Home Team Name  \
# 20                               Milan                 Switzerland
# 41                            Le Havre              Czechoslovakia
# 236                            Hanover                     Uruguay
# 244                           Dortmund                 Netherlands
# 252                           Dortmund                    Bulgaria
# 258                      Gelsenkirchen                 Netherlands
# 262                      Gelsenkirchen                   German DR
# 265                           Dortmund                 Netherlands
# 269                             Munich                 Netherlands
# 277                            Mendoza                 Netherlands
# 285                            Mendoza                 Netherlands
# 293                            Mendoza                    Scotland
# 295                            Cordoba                 Netherlands
# 300                            Cordoba                  Germany FR
# 302                       Buenos Aires                 Netherlands
# 307                       Buenos Aires                   Argentina
# 422                            Palermo                 Netherlands
# 432                           Cagliari                     England
# 446                            Palermo     rn">Republic of Ireland
# 451                              Milan                  Germany FR
# 472                      Washington Dc                 Netherlands
# 484                            Orlando                     Belgium
# 496                            Orlando                     Morocco
# 504                            Orlando                 Netherlands
# 509                             Dallas                 Netherlands
# 525                        Saint-Denis                 Netherlands
# 542                         Marseilles                 Netherlands
# 557                      Saint-Etienne                 Netherlands
# 569                           Toulouse                 Netherlands
# 574                         Marseilles                 Netherlands
# 576                         Marseilles                      Brazil
# 578                              Paris                 Netherlands
# 649                            Leipzig   rn">Serbia and Montenegro
# 665                          Stuttgart                 Netherlands
# 682                     Frankfurt/Main                 Netherlands
# 695                          Nuremberg                    Portugal
# 716                       Johannesburg                 Netherlands
# 731                             Durban                 Netherlands
# 751                          Cape Town                    Cameroon
# 760                             Durban                 Netherlands
# 764  Nelson Mandela Bay/Port Elizabeth                 Netherlands
# 768                          Cape Town                     Uruguay
# 771                       Johannesburg                 Netherlands
# 774                           Salvador                       Spain
# 789                       Porto Alegre                   Australia
# 805                          Sao Paulo                 Netherlands
# 827                           Brasilia                      Brazil
# 829                          Sao Paulo                 Netherlands
# 830                           Salvador                 Netherlands
# 832                          Fortaleza                 Netherlands
# 838                          Fortaleza                 Netherlands
# 847                           Salvador                 Netherlands
# 849                          Sao Paulo                 Netherlands
# 850                           Brasilia                      Brazil
#
#      Home Team Goals  Away Team Goals           Away Team Name  \
# 20                 3                2              Netherlands
# 41                 3                0              Netherlands
# 236                0                2              Netherlands
# 244                0                0                   Sweden
# 252                1                4              Netherlands
# 258                4                0                Argentina
# 262                0                2              Netherlands
# 265                2                0                   Brazil
# 269                1                2               Germany FR
# 277                3                0                  IR Iran
# 285                0                0                     Peru
# 293                3                2              Netherlands
# 295                5                1                  Austria
# 300                2                2              Netherlands
# 302                2                1                    Italy
# 307                3                1              Netherlands
# 422                1                1                    Egypt
# 432                0                0              Netherlands
# 446                1                1              Netherlands
# 451                2                1              Netherlands
# 472                2                1             Saudi Arabia
# 484                1                0              Netherlands
# 496                1                2              Netherlands
# 504                2                0  rn">Republic of Ireland
# 509                2                3                   Brazil
# 525                0                0                  Belgium
# 542                5                0           Korea Republic
# 557                2                2                   Mexico
# 569                2                1               Yugoslavia
# 574                2                1                Argentina
# 576                1                1              Netherlands
# 578                1                2                  Croatia
# 649                0                1              Netherlands
# 665                2                1            C�te d'Ivoire
# 682                0                0                Argentina
# 695                1                0              Netherlands
# 716                2                0                  Denmark
# 731                1                0                    Japan
# 751                1                2              Netherlands
# 760                2                1                 Slovakia
# 764                2                1                   Brazil
# 768                2                3              Netherlands
# 771                0                1                    Spain
# 774                1                5              Netherlands
# 789                2                3              Netherlands
# 805                2                0                    Chile
# 827                0                3              Netherlands
# 829                0                0                Argentina
# 830                0                0               Costa Rica
# 832                2                1                   Mexico
# 838                2                1                   Mexico
# 847                0                0               Costa Rica
# 849                0                0                Argentina
# 850                0                3              Netherlands
#
#                             Win conditions  Attendance  Half-time Home Goals  \
# 20                                             33000.0                     2
# 41    Czechoslovakia win after extra time      11000.0                     0
# 236                                            55100.0                     0
# 244                                            53700.0                     0
# 252                                            53300.0                     0
# 258                                            56548.0                     2
# 262                                            68348.0                     0
# 265                                            53700.0                     0
# 269                                            78200.0                     1
# 277                                            33431.0                     1
# 285                                            28125.0                     0
# 293                                            35130.0                     1
# 295                                            25050.0                     3
# 300                                            40750.0                     1
# 302                                            67433.0                     0
# 307        Argentina win after extra time      71483.0                     0
# 422                                            33288.0                     0
# 432                                            35267.0                     0
# 446                                            33288.0                     0
# 451                                            74559.0                     0
# 472                                            50535.0                     0
# 484                                            62387.0                     0
# 496                                            60578.0                     0
# 504                                            61355.0                     2
# 509                                            63500.0                     0
# 525                                            77000.0                     0
# 542                                            55000.0                     2
# 557                                            30600.0                     2
# 569                                            33500.0                     1
# 574                                            55000.0                     1
# 576       Brazil win on penalties (4 - 2)      54000.0                     0
# 578                                            45500.0                     1
# 649                                            43000.0                     0
# 665                                            52000.0                     2
# 682                                            48000.0                     0
# 695                                            41000.0                     1
# 716                                            83465.0                     0
# 731                                            62010.0                     0
# 751                                            63093.0                     0
# 760                                            61962.0                     1
# 764                                            40186.0                     0
# 768                                            62479.0                     1
# 771            Spain win after extra time      84490.0                     0
# 774                                            48173.0                     1
# 789                                            42877.0                     1
# 805                                            62996.0                     0
# 827                                            68034.0                     0
# 829    Argentina win on penalties (2 - 4)      63267.0                     0
# 830  Netherlands win on penalties (4 - 3)      51179.0                     0
# 832                                            58817.0                     0
# 838                                            58817.0                     0
# 847  Netherlands win on penalties (4 - 3)      51179.0                     0
# 849    Argentina win on penalties (2 - 4)      63267.0                     0
# 850                                            68034.0                     0
#
#      Half-time Away Goals                           Referee  \
# 20                      1                 EKLIND Ivan (SWE)
# 41                      0             LECLERCQ Lucien (FRA)
# 236                     1              PALOTAI Karoly (HUN)
# 244                     0            WINSEMANN Werner (CAN)
# 252                     2               BOSKOVIC Tony (AUS)
# 258                     0                DAVIDSON Bob (SCO)
# 262                     1              SCHEURER Ruedi (SUI)
# 265                     0            TSCHENSCHER Kurt (GER)
# 269                     2                 TAYLOR John (ENG)
# 277                     0  GONZALEZ ARCHUNDIA Alfonso (MEX)
# 285                     0                PROKOP Adolf (GDR)
# 293                     1              LINEMAYR Erich (AUT)
# 295                     0                 GORDON John (SCO)
# 300                     1          BARRETO RUIZ Ramon (URU)
# 302                     1              MARTINEZ Angel (ESP)
# 307                     0              GONELLA Sergio (ITA)
# 422                     0      SORIANO ALADREN Emilio (ESP)
# 432                     0              PETROVIC Zoran (SRB)
# 446                     1              VAUTROT Michel (FRA)
# 451                     0                LOUSTAU Juan (ARG)
# 472                     1            DIAZ VEGA Manuel (ESP)
# 484                     0            MARSIGLIA Renato (BRA)
# 496                     1      TEJADA NORIEGA Alberto (PER)
# 504                     0             MIKKELSEN Peter (DEN)
# 509                     0             BADILLA Rodrigo (CRC)
# 525                     0           COLLINA Pierluigi (ITA)
# 542                     0              WOJCIK Ryszard (POL)
# 557                     0          ALZEID Abdulrahman (KSA)
# 569                     0    GARCIA ARANDA Jose Maria (ESP)
# 574                     1        BRIZIO CARTER Arturo (MEX)
# 576                     0                 BUJSAIM Ali (UAE)
# 578                     2    GONZALEZ CHAVEZ Epifanio (PAR)
# 649                     1                 MERK Markus (GER)
# 665                     1                  RUIZ Oscar (COL)
# 682                     0       MEDINA CANTALEJO Luis (ESP)
# 695                     0             IVANOV Valentin (RUS)
# 716                     0             St�phane LANNOY (FRA)
# 731                     0             BALDASSI Hector (ARG)
# 751                     1                  POZO Pablo (CHI)
# 760                     0    Alberto UNDIANO MALLENCO (ESP)
# 764                     1            NISHIMURA Yuichi (JPN)
# 768                     1             Ravshan IRMATOV (UZB)
# 771                     0                 WEBB Howard (ENG)
# 774                     1              Nicola RIZZOLI (ITA)
# 789                     1             HAIMOUDI Djamel (ALG)
# 805                     0              Bakary GASSAMA (GAM)
# 827                     2             HAIMOUDI Djamel (ALG)
# 829                     0                C�neyt �AKIR (TUR)
# 830                     0             Ravshan IRMATOV (UZB)
# 832                     0               PROENCA Pedro (POR)
# 838                     0               PROENCA Pedro (POR)
# 847                     0             Ravshan IRMATOV (UZB)
# 849                     0                C�neyt �AKIR (TUR)
# 850                     2             HAIMOUDI Djamel (ALG)
#
#                             Assistant 1                           Assistant 2  \
# 20                  BERANEK Alois (AUT)             BONIVENTO Ferruccio (ITA)
# 41                       OLIVE D. (FRA)                     SDEZ Victor (FRA)
# 236                 KAZAKOV Pavel (URS)                  RAINEA Nicolae (ROU)
# 244              TSCHENSCHER Kurt (GER)                    THOMAS Clive (WAL)
# 252             BIWERSI Ferdinand (GER)               ESCHWEILER Walter (GER)
# 258              TSCHENSCHER Kurt (GER)                   KAZAKOV Pavel (URS)
# 262                LINEMAYR Erich (AUT)                    DELGADO Omar (COL)
# 265                  DAVIDSON Bob (SCO)                  SUPPIAH George (SIN)
# 269    GONZALEZ ARCHUNDIA Alfonso (MEX)              BARRETO RUIZ Ramon (URU)
# 277                  WURTZ Robert (FRA)                 COMESANA Miguel (ARG)
# 285       COEREZZA Norberto Angel (ARG)                  IVANOV Anatoly (URS)
# 293                PALOTAI Karoly (HUN)                     SEOUDI Hedi (TUN)
# 295      ITHURRALDE Arturo Andres (ARG)                    BOUZO Farouk (SYR)
# 300               COMESANA Miguel (ARG)                  COELHO Arnaldo (BRA)
# 302                PESTARINO Luis (ARG)           OROZCO GUERRERO Cesar (PER)
# 307            BARRETO RUIZ Ramon (URU)                  LINEMAYR Erich (AUT)
# 422        CODESAL MENDEZ Edgardo (MEX)  CARDELLINO DE SAN VICENTE Juan (URU)
# 432                HANSAL Mohamed (ALG)          CODESAL MENDEZ Edgardo (MEX)
# 446                LORENC Richard (AUS)                  HANSAL Mohamed (ALG)
# 451      JACOME GUERRERO Elias V. (ECU)                   MAURO Vincent (USA)
# 472               IVANOV Valentin (RUS)                   MARTON Sandor (HUN)
# 484             ALVES Paulo Jorge (BRA)              LISTKIEWICZ Michal (POL)
# 496               ZARATE Venancio (PAR)                 EVERSTIG Mikael (SWE)
# 504                DUNSTER Gordon (AUS)                 BRAZZALE Eugene (AUS)
# 509     AL GHATTAN Yousif Abdulla (BAH)                 FANAEI Mohammad (IRN)
# 525                MAZZEI Gennaro (ITA)                  ZAMMIT Emanuel (MLT)
# 542               POCIEGIEL Jacek (POL)                    DUPANOV Yuri (BLR)
# 557       TRESACO GRACIA Fernando (ESP)              GHADANFARI Hussain (KUW)
# 569                RAUSIS Laurent (SUI)              GRIGORESCU Nicolae (ROU)
# 574                   POWELL Owen (JAM)                SALINAS Reynaldo (HON)
# 576            GHADANFARI Hussain (KUW)               AL MUSAWI Mohamed (OMA)
# 578                ZAMMIT Emanuel (MLT)                     FRED Lencie (VAN)
# 649             SCHRAER Christian (GER)              SALVER Jan-Hendrik (GER)
# 665               TAMAYO Fernando (ECU)                      NAVIA Jose (COL)
# 682  GIRALDEZ CARRASCO Victoriano (ESP)          MEDINA HERNANDEZ Pedro (ESP)
# 695               GOLUBEV Nikolai (RUS)                  VOLNIN Evgueni (RUS)
# 716                 DANSAULT Eric (FRA)                     UGO Laurent (FRA)
# 731                 CASAS Ricardo (ARG)                  MAIDANA Hernan (ARG)
# 751             BASUALTO Patricio (CHI)               MONDRIA Francisco (CHI)
# 760               MARTINEZ Fermin (ESP)                      YUSTE Juan (ESP)
# 764                   SAGARA Toru (JPN)                  JEONG Hae Sang (KOR)
# 768                ILYASOV Rafael (UZB)              KOCHKAROV Bakhadyr (KGZ)
# 771                   Darren CANN (ENG)               MULLARKEY Michael (ENG)
# 774               Renato FAVERANI (ITA)                  Andrea STEFANI (ITA)
# 789                ACHIK Redouane (MAR)               ETCHIALI Abdelhak (ALG)
# 805            MENKOUANDE Evarist (CMR)                KABANDA Felicien (RWA)
# 827                ACHIK Redouane (MAR)               ETCHIALI Abdelhak (ALG)
# 829                DURAN Bahattin (TUR)                     ONGUN Tarik (TUR)
# 830         RASULOV Abduxamidullo (UZB)              KOCHKAROV Bakhadyr (KGZ)
# 832               MIRANDA Bertino (POR)                      TRIGO Jose (POR)
# 838               MIRANDA Bertino (POR)                      TRIGO Jose (POR)
# 847         RASULOV Abduxamidullo (UZB)              KOCHKAROV Bakhadyr (KGZ)
# 849                DURAN Bahattin (TUR)                     ONGUN Tarik (TUR)
# 850                ACHIK Redouane (MAR)               ETCHIALI Abdelhak (ALG)
#
#       RoundID    MatchID Home Team Initials Away Team Initials
# 20        204       1133                SUI                NED
# 41        206       1172                TCH                NED
# 236       262       2098                URU                NED
# 244       262       2097                NED                SWE
# 252       262       1990                BUL                NED
# 258       263       1948                NED                ARG
# 262       263       2067                GDR                NED
# 265       263       1983                NED                BRA
# 269       605       2063                NED                FRG
# 277       278       2388                NED                IRN
# 285       278       2394                NED                PER
# 293       278       2395                SCO                NED
# 295       279       2220                NED                AUT
# 300       279       2348                FRG                NED
# 302       279       2391                NED                ITA
# 307       639       2198                ARG                NED
# 422       322        151                NED                EGY
# 432       322        160                ENG                NED
# 446       322        228                IRL                NED
# 451       323        196                FRG                NED
# 472       337       3058                NED                KSA
# 484       337       3069                BEL                NED
# 496       337       3081                MAR                NED
# 504       338       3089                NED                IRL
# 509       796       3098                NED                BRA
# 525      1014       8733                NED                BEL
# 542      1014       8749                NED                KOR
# 557      1014       8766                NED                MEX
# 569      1024       8778                NED                YUG
# 574      1025       8784                NED                ARG
# 576      1026       8785                BRA                NED
# 578      1028       8787                NED                CRO
# 649  97410100   97410006                SCG                NED
# 665  97410100   97410022                NED                CIV
# 682  97410100   97410037                NED                ARG
# 695  97410200   97410052                POR                NED
# 716    249722  300061478                NED                DEN
# 731    249722  300111117                NED                JPN
# 751    249722  300061473                CMR                NED
# 760    249717  300111113                NED                SVK
# 764    249718  300061507                NED                BRA
# 768    249719  300061512                URU                NED
# 771    249721  300061509                NED                ESP
# 774    255931  300186510                ESP                NED
# 789    255931  300186478                AUS                NED
# 805    255931  300186470                NED                CHI
# 827    255957  300186502                BRA                NED
# 829    255955  300186490                NED                ARG
# 830    255953  300186488                NED                CRC
# 832    255951  300186508                NED                MEX
# 838    255951  300186508                NED                MEX
# 847    255953  300186488                NED                CRC
# 849    255955  300186490                NED                ARG
# 850    255957  300186502                BRA                NED

# %% [markdown]
# Next, let's try and figure out how many games the USA played in the 2014 World Cup.

# %%
# Number of games the USA played in the 2014 world cup
print(len(df.loc[((df['Home Team Name'] == 'USA') | (df['Away Team Name'] == 'USA')) & (df.Year == 2014)]))
df.loc[((df['Home Team Name'] == 'USA') | (df['Away Team Name'] == 'USA')) & (df.Year == 2014)]
# Out:
# 5
#      Year              Datetime        Stage            Stadium       City  \
# 785  2014  16 Jun 2014 - 19:00       Group G  Estadio das Dunas     Natal
# 803  2014  22 Jun 2014 - 18:00       Group G     Arena Amazonia    Manaus
# 816  2014  26 Jun 2014 - 13:00       Group G   Arena Pernambuco    Recife
# 835  2014  01 Jul 2014 - 17:00   Round of 16   Arena Fonte Nova  Salvador
# 843  2014  01 Jul 2014 - 17:00   Round of 16   Arena Fonte Nova  Salvador
#
#     Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 785          Ghana                1                2            USA
# 803            USA                2                2       Portugal
# 816            USA                0                1        Germany
# 835        Belgium                2                1            USA
# 843        Belgium                2                1            USA
#
#                     Win conditions  Attendance  Half-time Home Goals  \
# 785                                    39760.0                     0
# 803                                    40123.0                     0
# 816                                    41876.0                     0
# 835  Belgium win after extra time      51227.0                     0
# 843  Belgium win after extra time      51227.0                     0
#
#      Half-time Away Goals                Referee                  Assistant 1  \
# 785                     1   ERIKSSON Jonas (SWE)      KLASENIUS Mathias (SWE)
# 803                     1    PITANA Nestor (ARG)         MAIDANA Hernan (ARG)
# 816                     0  Ravshan IRMATOV (UZB)  RASULOV Abduxamidullo (UZB)
# 835                     0  HAIMOUDI Djamel (ALG)         ACHIK Redouane (MAR)
# 843                     0  HAIMOUDI Djamel (ALG)         ACHIK Redouane (MAR)
#
#                   Assistant 2  RoundID    MatchID Home Team Initials  \
# 785     WARNMARK Daniel (SWE)   255931  300186512                GHA
# 803  BELATTI Juan Pablo (ARG)   255931  300186483                USA
# 816  KOCHKAROV Bakhadyr (KGZ)   255931  300186469                USA
# 835   ETCHIALI Abdelhak (ALG)   255951  300186497                BEL
# 843   ETCHIALI Abdelhak (ALG)   255951  300186497                BEL
#
#     Away Team Initials
# 785                USA
# 803                POR
# 816                GER
# 835                USA
# 843                USA

# %% [markdown]
# Now, let's try to find out how many countries participated in the 1986 World Cup.

# %% [markdown]
# Hint 1: as a first step, create a new dataset that only contains games in that year.
#
# Hint 2: You can use `.unique()` to make sure you don't end up with duplicate country names.

# %%
# Number of countries participated in the 1986 world cup
print(df.loc[df.Year == 1986,['Home Team Name']].nunique())
print(df.loc[df.Year == 1986,['Away Team Name']].nunique())
print('\n')
Y1986_df = df[df.Year == 1986]
Y1986_home_df = Y1986_df['Home Team Name']
Y1986_home_ls = list(Y1986_home_df)
print(len(Y1986_home_ls))
Y1986_away_df = Y1986_df['Away Team Name']
Y1986_away_ls = list(Y1986_away_df)
print(len(Y1986_away_ls))
Y1986_combo_ls = Y1986_home_ls + Y1986_away_ls
print(len(Y1986_combo_ls))
Y1986_uniqu_st = set(Y1986_combo_ls)

print(type(Y1986_uniqu_ls)," >>> ",len(Y1986_uniqu_st),'\n\n')

print("one-line command:",list(df.loc[df.Year == 1986,'Home Team Name']))
# Out:
# Home Team Name    24
# dtype: int64
# Away Team Name    24
# dtype: int64
#
#
# 52
# 52
# 104
# <class 'set'>  >>>  24
#
#
# one-line command: ['Bulgaria', 'Canada', 'Spain', 'Soviet Union', 'Argentina', 'Morocco', 'Algeria', 'Belgium', 'Portugal', 'Paraguay', 'Scotland', 'Uruguay', 'Italy', 'France', 'Korea Republic', 'Hungary', 'Brazil', 'England', 'Northern Ireland', 'Mexico', 'Poland', 'Iraq', 'Denmark', 'Germany FR', 'Hungary', 'Soviet Union', 'Korea Republic', 'Argentina', 'Paraguay', 'Iraq', 'Portugal', 'England', 'Northern Ireland', 'Algeria', 'Scotland', 'Denmark', 'Soviet Union', 'Mexico', 'Argentina', 'Brazil', 'Italy', 'Morocco', 'England', 'Denmark', 'Brazil', 'Germany FR', 'Spain', 'Argentina', 'France', 'Argentina', 'France', 'Argentina']

# %% [markdown]
# In World Cup history, how many matches had 5 goals or more in total?

# %%
# Number of matches that had 5 or more goals in total
print("unique:",df.loc[df['Home Team Goals'] + df['Away Team Goals'] >= 5, 'MatchID'].nunique())
print(len(df.loc[df['Home Team Goals'] + df['Away Team Goals'] >= 5, 'MatchID']))
print("redundancy:",len(df.loc[df['Home Team Goals'] + df['Away Team Goals'] >= 5, 'MatchID']) - df.loc[df['Home Team Goals'] + df['Away Team Goals'] >= 5, 'MatchID'].nunique())
# Out:
# unique: 146
# 147
# redundancy: 1

# %% [markdown]
# ## Changing values and creating new columns

# %% [markdown]
# With the information you currently have in your `df`, create a new column, "Half-time Goals."

# %%
# Create a new column 'Half-time Goals' in df
df['Half-time Goals'] = df['Half-time Home Goals'] + df['Half-time Away Goals']

# %% [markdown]
# Run the code below. You'll notice that for Korea, there are records for both North-Korea (Korea DPR) and South-Korea (Korea Republic).

# %%
# Print all records containing the string 'Korea'
df.loc[df['Home Team Name'].str.contains('Korea'), 'Home Team Name']
# Out:
# 179         Korea DPR
# 187         Korea DPR
# 374    Korea Republic
# 386    Korea Republic
# 434    Korea Republic
# 444    Korea Republic
# 480    Korea Republic
# 524    Korea Republic
# 593    Korea Republic
# 609    Korea Republic
# 635    Korea Republic
# 642    Korea Republic
# 655    Korea Republic
# 710    Korea Republic
# 753         Korea DPR
# 802    Korea Republic
# 818    Korea Republic
# Name: Home Team Name, dtype: object

# %% [markdown]
# Imagine that, for some reason, we simply want Korea listed as one entry, so we want to replace every "Home Team Name" and "Away Team Name" entry that contains "Korea" to simply "Korea". In the same way, we want to change the columns "Home Team Initials" and "Away Team Initials" to NSK (North & South Korea) instead of "KOR" and "PRK".

# %%
# Update the 'Home Team Name' and 'Home Team Initials' columns 
df.loc[df['Home Team Name'].str.contains('Korea'), ['Home Team Name']] = 'Korea'
print(df.loc[df['Home Team Name'].str.contains('Korea'), 'Home Team Name'])
df.loc[df['Away Team Name'].str.contains('Korea'), ['Away Team Name']] = 'Korea'
print(df.loc[df['Away Team Name'].str.contains('Korea'), 'Away Team Name'])

df.loc[df['Home Team Initials'] == 'KOR', ['Home Team Initials']] = 'NSK'
print(df.loc[df['Home Team Initials'].str.contains('KOR'), 'Home Team Initials'])
df.loc[df['Away Team Initials'] == 'KOR', ['Away Team Initials']] = 'NSK'
print(df.loc[df['Away Team Initials'].str.contains('KOR'), 'Away Team Initials'])
df.loc[df['Home Team Initials'] == 'PRK', ['Home Team Initials']] = 'NSK'
print(df.loc[df['Home Team Initials'].str.contains('PRK'), 'Home Team Initials'])
df.loc[df['Away Team Initials'] == 'PRK', ['Away Team Initials']] = 'NSK'
print(df.loc[df['Away Team Initials'].str.contains('PRK'), 'Away Team Initials'])
# Out:
# 179    Korea
# 187    Korea
# 374    Korea
# 386    Korea
# 434    Korea
# 444    Korea
# 480    Korea
# 524    Korea
# 593    Korea
# 609    Korea
# 635    Korea
# 642    Korea
# 655    Korea
# 710    Korea
# 753    Korea
# 802    Korea
# 818    Korea
# Name: Home Team Name, dtype: object
# 80     Korea
# 88     Korea
# 171    Korea
# 195    Korea
# 364    Korea
# 421    Korea
# 464    Korea
# 490    Korea
# 542    Korea
# 556    Korea
# 625    Korea
# 639    Korea
# 640    Korea
# 672    Korea
# 691    Korea
# 721    Korea
# 725    Korea
# 737    Korea
# 742    Korea
# 756    Korea
# 788    Korea
# Name: Away Team Name, dtype: object
# Series([], Name: Home Team Initials, dtype: object)
# Series([], Name: Away Team Initials, dtype: object)
# Series([], Name: Home Team Initials, dtype: object)
# Series([], Name: Away Team Initials, dtype: object)

# %% [markdown]
# Make sure to verify your answer!

# %%
# Check the updated columns
df[(df['Home Team Name'] == 'Korea') | (df['Away Team Name'] == 'Korea')]
# Out:
#      Year              Datetime           Stage  \
# 80   1954  17 Jun 1954 - 18:00          Group 2
# 88   1954  20 Jun 1954 - 17:00          Group 2
# 171  1966  12 Jul 1966 - 19:30          Group 4
# 179  1966  15 Jul 1966 - 19:30          Group 4
# 187  1966  19 Jul 1966 - 19:30          Group 4
# 195  1966  23 Jul 1966 - 15:00   Quarter-finals
# 364  1986  02 Jun 1986 - 12:00          Group A
# 374  1986  05 Jun 1986 - 16:00          Group A
# 386  1986  10 Jun 1986 - 12:00          Group A
# 421  1990  12 Jun 1990 - 17:00          Group E
# 434  1990  17 Jun 1990 - 21:00          Group E
# 444  1990  21 Jun 1990 - 17:00          Group E
# 464  1994  17 Jun 1994 - 19:30          Group C
# 480  1994  23 Jun 1994 - 19:30          Group C
# 490  1994  27 Jun 1994 - 16:00          Group C
# 524  1998  13 Jun 1998 - 17:30          Group E
# 542  1998  20 Jun 1998 - 21:00          Group E
# 556  1998  25 Jun 1998 - 16:00          Group E
# 593  2002  04 Jun 2002 - 20:30          Group D
# 609  2002  10 Jun 2002 - 15:30          Group D
# 625  2002  14 Jun 2002 - 20:30          Group D
# 635  2002  18 Jun 2002 - 20:30      Round of 16
# 639  2002  22 Jun 2002 - 15:30   Quarter-finals
# 640  2002  25 Jun 2002 - 20:30      Semi-finals
# 642  2002  29 Jun 2002 - 20:00      Third place
# 655  2006  13 Jun 2006 - 15:00          Group G
# 672  2006  18 Jun 2006 - 21:00          Group G
# 691  2006  23 Jun 2006 - 21:00          Group G
# 710  2010  12 Jun 2010 - 13:30          Group B
# 721  2010  15 Jun 2010 - 20:30          Group G
# 725  2010  17 Jun 2010 - 13:30          Group B
# 737  2010  21 Jun 2010 - 13:30          Group G
# 742  2010  22 Jun 2010 - 20:30          Group B
# 753  2010  25 Jun 2010 - 16:00          Group G
# 756  2010  26 Jun 2010 - 16:00      Round of 16
# 788  2014  17 Jun 2014 - 18:00          Group H
# 802  2014  22 Jun 2014 - 16:00          Group H
# 818  2014  26 Jun 2014 - 17:00          Group H
#
#                                Stadium                                City  \
# 80                            Hardturm                             Zurich
# 88                          Charmilles                             Geneva
# 171                      Ayresome Park                      Middlesbrough
# 179                      Ayresome Park                      Middlesbrough
# 187                      Ayresome Park                      Middlesbrough
# 195                      Goodison Park                          Liverpool
# 364     Estadio Ol�mpico Universitario                        Mexico City
# 374     Estadio Ol�mpico Universitario                        Mexico City
# 386                         Cuauhtemoc                             Puebla
# 421             Marc Antonio Bentegodi                             Verona
# 434                        Dacia Arena                              Udine
# 444                             Friuli                              Udine
# 464                        Cotton Bowl                             Dallas
# 480                    Foxboro Stadium                             Boston
# 490                        Cotton Bowl                             Dallas
# 524                   Stade de Gerland                               Lyon
# 542                    Stade V�lodrome                         Marseilles
# 556                   Parc des Princes                              Paris
# 593           Busan Asiad Main Stadium                              Busan
# 609            Daegu World Cup Stadium                              Daegu
# 625           Incheon Football Stadium                            Incheon
# 635          Daejeon World Cup Stadium                            Daejeon
# 639          Gwangju World Cup Stadium                            Gwangju
# 640            Seoul World Cup Stadium                              Seoul
# 642            Daegu World Cup Stadium                              Daegu
# 655  FIFA World Cup Stadium, Frankfurt                     Frankfurt/Main
# 672                     Zentralstadion                            Leipzig
# 691    FIFA World Cup Stadium, Hanover                            Hanover
# 710             Port Elizabeth Stadium  Nelson Mandela Bay/Port Elizabeth
# 721                 Ellis Park Stadium                       Johannesburg
# 725                Soccer City Stadium                       Johannesburg
# 737                  Cape Town Stadium                          Cape Town
# 742                     Durban Stadium                             Durban
# 753                   Mbombela Stadium                          Nelspruit
# 756             Port Elizabeth Stadium  Nelson Mandela Bay/Port Elizabeth
# 788                     Arena Pantanal                             Cuiaba
# 802                  Estadio Beira-Rio                       Porto Alegre
# 818                 Arena de Sao Paulo                          Sao Paulo
#
#     Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 80         Hungary                9                0          Korea
# 88          Turkey                7                0          Korea
# 171   Soviet Union                3                0          Korea
# 179          Korea                1                1          Chile
# 187          Korea                1                0          Italy
# 195       Portugal                5                3          Korea
# 364      Argentina                3                1          Korea
# 374          Korea                1                1       Bulgaria
# 386          Korea                2                3          Italy
# 421        Belgium                2                0          Korea
# 434          Korea                1                3          Spain
# 444          Korea                0                1        Uruguay
# 464          Spain                2                2          Korea
# 480          Korea                0                0        Bolivia
# 490        Germany                3                2          Korea
# 524          Korea                1                3         Mexico
# 542    Netherlands                5                0          Korea
# 556        Belgium                1                1          Korea
# 593          Korea                2                0         Poland
# 609          Korea                1                1            USA
# 625       Portugal                0                1          Korea
# 635          Korea                2                1          Italy
# 639          Spain                0                0          Korea
# 640        Germany                1                0          Korea
# 642          Korea                2                3         Turkey
# 655          Korea                2                1           Togo
# 672         France                1                1          Korea
# 691    Switzerland                2                0          Korea
# 710          Korea                2                0         Greece
# 721         Brazil                2                1          Korea
# 725      Argentina                4                1          Korea
# 737       Portugal                7                0          Korea
# 742        Nigeria                2                2          Korea
# 753          Korea                0                3  C�te d'Ivoire
# 756        Uruguay                2                1          Korea
# 788         Russia                1                1          Korea
# 802          Korea                2                4        Algeria
# 818          Korea                0                1        Belgium
#
#                                Win conditions  ...  Half-time Home Goals  \
# 80                                             ...                     4
# 88                                             ...                     4
# 171                                            ...                     2
# 179                                            ...                     0
# 187                                            ...                     1
# 195                                            ...                     2
# 364                                            ...                     2
# 374                                            ...                     0
# 386                                            ...                     0
# 421                                            ...                     0
# 434                                            ...                     1
# 444                                            ...                     0
# 464                                            ...                     0
# 480                                            ...                     0
# 490                                            ...                     3
# 524                                            ...                     1
# 542                                            ...                     2
# 556                                            ...                     1
# 593                                            ...                     1
# 609                                            ...                     0
# 625                                            ...                     0
# 635                       Win on Golden Goal   ...                     0
# 639  Korea Republic win on penalties (3 - 5)   ...                     0
# 640                                            ...                     0
# 642                                            ...                     1
# 655                                            ...                     0
# 672                                            ...                     1
# 691                                            ...                     1
# 710                                            ...                     1
# 721                                            ...                     0
# 725                                            ...                     2
# 737                                            ...                     1
# 742                                            ...                     1
# 753                                            ...                     0
# 756                                            ...                     1
# 788                                            ...                     0
# 802                                            ...                     0
# 818                                            ...                     0
#
#      Half-time Away Goals                           Referee  \
# 80                      0            VINCENTI Raymond (FRA)
# 88                      0              MARINO Esteban (URU)
# 171                     0            GARDEAZABAL Juan (ESP)
# 179                     1          KANDIL Aly Hussein (EGY)
# 187                     0             SCHWINTE Pierre (FRA)
# 195                     3          ASHKENAZI Menachem (ISR)
# 364                     0  SANCHEZ ARMINIO Victoriano (ESP)
# 374                     1     AL SHANAR Fallaj Khuzam (KSA)
# 386                     1                 SOCHA David (USA)
# 421                     0               MAURO Vincent (USA)
# 434                     1    JACOME GUERRERO Elias V. (ECU)
# 444                     0               LANESE Tullio (ITA)
# 464                     0             MIKKELSEN Peter (DEN)
# 480                     0              MOTTRAM Leslie (SCO)
# 490                     0                QUINIOU Joel (FRA)
# 524                     0                BENKO Gunter (AUT)
# 542                     0              WOJCIK Ryszard (POL)
# 556                     0              REZENDE Marcio (BRA)
# 593                     0                  RUIZ Oscar (COL)
# 609                     1                   MEIER Urs (SUI)
# 625                     0               SANCHEZ Angel (ARG)
# 635                     0                MORENO Byron (ECU)
# 639                     0           EL GHANDOUR Gamal (EGY)
# 640                     0                   MEIER Urs (SUI)
# 642                     3                   MANE Saad (KUW)
# 655                     1                 POLL Graham (ENG)
# 672                     0            ARCHUNDIA Benito (MEX)
# 691                     0            ELIZONDO Horacio (ARG)
# 710                     0              HESTER Michael (NZL)
# 721                     0               KASSAI Viktor (HUN)
# 725                     1          DE BLEECKERE Frank (BEL)
# 737                     0                  POZO Pablo (CHI)
# 742                     1        Oleg�rio BENQUEREN�A (POR)
# 753                     2    Alberto UNDIANO MALLENCO (ESP)
# 756                     0              Wolfgang STARK (GER)
# 788                     0               PITANA Nestor (ARG)
# 802                     3               ROLDAN Wilmar (COL)
# 818                     0                Ben WILLIAMS (AUS)
#
#                             Assistant 1               Assistant 2   RoundID  \
# 80              VON GUNTER Albert (SUI)        STEINER Carl (AUT)       211
# 88             ORLANDINI Vincenzo (ITA)  SCHONHOLZER Ernest (SUI)       211
# 171            KANDIL Aly Hussein (EGY)    DIENST Gottfried (SUI)       238
# 179              CRAWFORD William (SCO)          FINNEY Jim (ENG)       238
# 187                    ADAIR John (NIR)         TAYLOR John (ENG)       238
# 195                   GALBA Karol (TCH)     SCHWINTE Pierre (FRA)       239
# 364          GONZALEZ ROA Gabriel (PAR)  DIAZ PALACIO Jesus (COL)       308
# 374                     IGNA Ioan (ROU)      BUTENKO Valeri (RUS)       308
# 386                 URREA Joaquin (MEX)     AL SHARIF Jamal (SYR)       308
# 421                   SNODDY Alan (NIR)     COURTNEY George (ENG)       322
# 434               MAGNI Pierluigi (ITA)        LOUSTAU Juan (ARG)       322
# 444           DIRAMBA Jean Fidele (GAB)         JOUINI Neji (TUN)       322
# 464  CHRISTENSEN Carl-Johan Meyer (DEN)         PEARSON Roy (ENG)       337
# 480                   MATTHYS Luc (BEL)     EVERSTIG Mikael (SWE)       337
# 490               IVANOV Valentin (RUS)  HASSAN Abdel-Magid (EGY)       337
# 524                   FRED Lencie (VAN)     SCHNEIDER Erich (GER)      1014
# 542               POCIEGIEL Jacek (POL)        DUPANOV Yuri (BLR)      1014
# 556                 PINTO Arnaldo (BRA)   ARANGO Jorge Luis (COL)      1014
# 593                  DORIRI Elise (VAN)       LINDBERG Leif (SWE)  43950100
# 609                 BEREUTER Egon (AUT)       TOMUSANGE Ali (UGA)  43950100
# 625                  ALTRAIFI Ali (KSA)      SZEKELY Ferenc (HUN)  43950100
# 635               RATTALINO Jorge (ARG)      SZEKELY Ferenc (HUN)  43950200
# 639                 TOMUSANGE Ali (UGA)   RAGOONATH Michael (TRI)  43950300
# 640              ARNAULT Frederic (FRA)         AMLER Evzen (CZE)  43950400
# 642                  ALTRAIFI Ali (KSA)      VERGARA Hector (CAN)  43950500
# 655                  SHARP Philip (ENG)        TURNER Glenn (ENG)  97410100
# 672                  RAMIREZ Jose (MEX)      VERGARA Hector (CAN)  97410100
# 691                  GARCIA Dario (ARG)       OTERO Rodolfo (ARG)  97410100
# 710             HINTZ Jan Hendrik (NZL)     MAKASINI Tevita (TGA)    249722
# 721                    EROS Gabor (HUN)         VAMOS Tibor (HUN)    249722
# 725                 HERMANS Peter (BEL)      VROMANS Walter (BEL)    249722
# 737             BASUALTO Patricio (CHI)   MONDRIA Francisco (CHI)    249722
# 742                 CARDINAL Jose (POR)     MIRANDA Bertino (POR)    249722
# 753               MARTINEZ Fermin (ESP)          YUSTE Juan (ESP)    249722
# 756            SALVER Jan-Hendrik (GER)         PICKEL Mike (GER)    249717
# 788                MAIDANA Hernan (ARG)  BELATTI Juan Pablo (ARG)    255931
# 802                  DIAZ Eduardo (COL)   LESCANO Christian (ECU)    255931
# 818                 CREAM Matthew (AUS)          ANAZ Hakan (AUS)    255931
#
#        MatchID  Home Team Initials Away Team Initials Half-time Goals
# 80        1294                 HUN                NSK               4
# 88        1304                 TUR                NSK               4
# 171       1710                 URS                NSK               2
# 179       1609                 NSK                CHI               1
# 187       1679                 NSK                ITA               1
# 195       1702                 POR                NSK               5
# 364        395                 ARG                NSK               2
# 374        460                 NSK                BUL               1
# 386        643                 NSK                ITA               1
# 421         57                 BEL                NSK               0
# 434        175                 NSK                ESP               2
# 444        290                 NSK                URU               0
# 464       3050                 ESP                NSK               0
# 480       3065                 NSK                BOL               0
# 490       3076                 GER                NSK               3
# 524       8732                 NSK                MEX               1
# 542       8749                 NED                NSK               2
# 556       8765                 BEL                NSK               1
# 593   43950014                 NSK                POL               1
# 609   43950030                 NSK                USA               1
# 625   43950047                 POR                NSK               0
# 635   43950056                 NSK                ITA               0
# 639   43950059                 ESP                NSK               0
# 640   43950061                 GER                NSK               0
# 642   43950063                 NSK                TUR               4
# 655   97410014                 NSK                TOG               1
# 672   97410029                 FRA                NSK               1
# 691   97410046                 SUI                NSK               1
# 710  300061459                 NSK                GRE               1
# 721  300061490                 BRA                NSK               0
# 725  300061458                 ARG                NSK               3
# 737  300061487                 POR                NSK               1
# 742  300111115                 NGA                NSK               2
# 753  300061486                 NSK                CIV               2
# 756  300061504                 URU                NSK               1
# 788  300186499                 RUS                NSK               0
# 802  300186495                 NSK                ALG               3
# 818  300186480                 NSK                BEL               0
#
# [38 rows x 21 columns]

# %% [markdown]
# ## Summary
#
# In this lab, you learned how to access data within Pandas!
